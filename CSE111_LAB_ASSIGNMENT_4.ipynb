# %%
#TASK 1
class Calculator:
    def __init__(self):
        pass
    
    def add(self, num_1, num_2):
        return f"Result: {num_1 + num_2}"
    
    def subtract(self, num_1, num_2):
        return f"Result: {num_1 - num_2}"
    
    def multiply(self, num_1, num_2):
        return f"Result: {num_1 * num_2}"
    
    def divide(self, num_1, num_2):
        if num_2 == 0:
            return "Undefined"
        return f"Result: {num_1 / num_2}"


obj = Calculator()

num_1 = int(input())
operator = input()
num_2 = int(input())

print("Let’s Calculate!")
print("Value 1:", num_1)
print("Operator:", operator)
print("Value 2:", num_2)

if operator == "+":
    print(obj.add(num_1, num_2))
elif operator == "-":
    print(obj.subtract(num_1, num_2))
elif operator == "*":
    print(obj.multiply(num_1, num_2))
elif operator == "/":
    print(obj.divide(num_1, num_2))
# Out:
# 1
# +
# 2
# Let’s Calculate!
# Value 1: 1
# Operator: +
# Value 2: 2
# Result: 3

# %%
#TASK 2
class Customer:
    def __init__(self, name):
        self.name = name

    def greet(self, name= None):
        if name== None:            
            print("Hello!") 
        else:
            print("Hello", name)
        
    def purchase(self, *shelby):
        print((f"{self.name}, you purchase {(len(shelby))}  item(s):"))                
        for i in shelby:
            print(i) 
            
customer_1 = Customer("Sam")
customer_1.greet()
customer_1.purchase("chips", "chocolate", "orange juice")
print("-----------------------------")
customer_2 = Customer("David")
customer_2.greet("David")
customer_2.purchase("orange juice")
# Out:
# Hello!
# Sam, you purchase 3  item(s):
# chips
# chocolate
# orange juice
# -----------------------------
# Hello David
# David, you purchase 1  item(s):
# orange juice

# %%
#TASK 3
class Panda:
    def __init__(self, name, gender, age):
        self.name= name
        self.gender= gender
        self.age= age
        
    def sleep(self, time= None):    
        if time== None:
            return f"{self.name}'s duration is unknown thus should have only bamboo leaves"
        else:
            if 3<=time<=5:
                return f"{self.name} sleeps {time} hours daily and should have Mixed Veggies "
            elif 6<=time<=8:
                return f"{self.name} sleeps {time} hours daily and should have Eggplant & Tofu"
            elif 9<=time<=11:
                return f"{self.name} sleeps {time} hours daily and should have Broccoli Chicken"

    
panda1 = Panda("Kunfu","Male", 5)
panda2=Panda("Pan Pan","Female",3)
panda3=Panda("Ming Ming","Female",8)
print("{} is a {} Panda Bear who is {} years old".format(panda1.name,panda1.gender,panda1.age))
print("{} is a {} Panda Bear who is {} years old".format(panda2.name,panda2.gender,panda2.age))
print("{} is a {} Panda Bear who is {} years old".format(panda3.name,panda3.gender,panda3.age))
print("===========================")
print(panda2.sleep(10))
print(panda1.sleep(4))
print(panda3.sleep())
# Out:
# Kunfu is a Male Panda Bear who is 5 years old
# Pan Pan is a Female Panda Bear who is 3 years old
# Ming Ming is a Female Panda Bear who is 8 years old
# ...
# Pan Pan sleeps 10 hours daily and should have Broccoli Chicken
# Kunfu sleeps 4 hours daily and should have Mixed Veggies
# Ming Ming's duration is unknown thus should have only bamboo leaves

# %%
#TASK 4
class Cat:    
    var_1= ""
    var_2= "" #Two useles variables lol
    
    def __init__(self, color= None, pos= None):
        if color== None and pos== None:
            color= "White"
            pos= "sitting"
            self.color= color
            self.pos= pos
        elif pos== None:
            pos= "sitting"
            self.color= color 
            self.pos= pos
        else:
            self.color= color
            self.pos= pos
            
    def printCat(self):
        print(self.color, "cat is", self.pos)
        
    def changeColor(self, new_col):
        self.color= new_col

c1 = Cat()
c2 = Cat("Black")
c3 = Cat("Brown", "jumping")
c4 = Cat("Red", "purring")
c1.printCat()
c2.printCat()
c3.printCat()
c4.printCat()
c1.changeColor("Blue")
c3.changeColor("Purple")
c1.printCat()
c3.printCat()
# Out:
# White cat is sitting
# Black cat is sitting
# Brown cat is jumping
# Red cat is purring
# Blue cat is sitting
# Purple cat is jumping

# %%
#TASK 5
class Student:
    def __init__(self, name= "default student"):
        self.name= name
               
    def quizcalc(self, *num):
        sum= 0
        for i in num:
            sum+= i
        num= sum/3    
        self.num= num
        
    def printdetail(self):
        print("Hello", self.name)
        print("Your average quiz score is", self.num)  
    
        
s1 = Student()
s1.quizcalc(10)
print('--------------------------------')
s1.printdetail()
s2 = Student('Harry')
s2.quizcalc(10,8)
print('--------------------------------')
s2.printdetail()
s3 = Student('Hermione')
s3.quizcalc(10,9,10)
print('--------------------------------')
s3.printdetail()
# Out:
# --------------------------------
# Hello default student
# Your average quiz score is 3.3333333333333335
# --------------------------------
# Hello Harry
# Your average quiz score is 6.0
# --------------------------------
# Hello Hermione
# Your average quiz score is 9.666666666666666

# %%
#TASK 6
class Vehicle:
    def __init__(self):
        self.num_1 = 0
        self.num_2 = 0

    def print_position(self):
        print(f"({self.num_1},{self.num_2})")

    def moveUp(self):
        self.num_2+= 1

    def moveLeft(self):
        self.num_1-= 1

    def moveDown(self):
        self.num_2-= 1

    def moveRight(self):
        self.num_1+= 1


car = Vehicle()
car.print_position()
car.moveUp()
car.print_position()
car.moveLeft()
car.print_position()
car.moveDown()
car.print_position()
car.moveRight()
# Out:
# (0,0)
# (0,1)
# (-1,1)
# (-1,0)

# %%
#TASK 7
class Programmer:
    def __init__(self, name, lan, xp):
        print("Horray! A new programmer is born")
        self.name = name
        self.lan = lan
        self.xp = xp
    
    def addExp(self, new_xp):
        print("Updating experience of", self.name)
        self.xp+= new_xp
    
    def printDetails(self):
        print("Name:", self.name)
        print("Language:", self.lan)
        print("Experience:", self.xp, "years")
    
    
p1 = Programmer("Ethen Hunt", "Java", 10)
p1.printDetails()
print('--------------------------')
p2 = Programmer("James Bond", "C++", 7)
p2.printDetails()
print('--------------------------')
p3 = Programmer("Jon Snow", "Python", 4)
p3.printDetails()
p3.addExp(5)
p3.printDetails()
# Out:
# Horray! A new programmer is born
# Name: Ethen Hunt
# Language: Java
# Experience: 10 years
# --------------------------
# Horray! A new programmer is born
# Name: James Bond
# Language: C++
# Experience: 7 years
# --------------------------
# Horray! A new programmer is born
# Name: Jon Snow
# Language: Python
# Experience: 4 years
# Updating experience of Jon Snow
# Name: Jon Snow
# Language: Python
# Experience: 9 years

# %%
#TASK 8
class Student:
    def __init__(self, name, id, dept= "CSE"):
        self.name= name
        self.id= id
        self.dept= dept
        
    def dailyEffort(self, time):
        self.time= time
        
    def printDetails(self):
        print("Name:", self.name)
        print("ID:", self.id)
        print("Department:", self.dept)
        print(f"Daily Effort: {self.time} hour(s)")
        if self.time<= 2:
            print("Suggestion: Should give more effort!")
        elif self.time<=4:
            print("Suggestion: Keep up the good work!")
        else:
            print("Suggestion: Excellent! Now motivate others.")
    
harry = Student('Harry Potter', 123)
harry.dailyEffort(3)
harry.printDetails()
print('========================')
john = Student("John Wick", 456, "BBA")
john.dailyEffort(2)
john.printDetails()
print('========================')
naruto = Student("Naruto Uzumaki", 777, "Ninja")
naruto.dailyEffort(6)
naruto.printDetails()
# Out:
# Name: Harry Potter
# ID: 123
# Department: CSE
# Daily Effort: 3 hour(s)
# Suggestion: Keep up the good work!
# ...
# Name: John Wick
# ID: 456
# Department: BBA
# Daily Effort: 2 hour(s)
# Suggestion: Should give more effort!
# ...
# Name: Naruto Uzumaki
# ID: 777
# Department: Ninja
# Daily Effort: 6 hour(s)
# Suggestion: Excellent! Now motivate others.

# %%
#TASK 9
class Patient:
    def __init__(self, name, age):
        self.name= name
        self.age= age
        
    def add_Symptom(self, *sym):
        str_1= ""
        for i in sym:
            str_1+= i+ ", "
        sym= str_1[:len(str_1)-2]    
        self.sym= sym
        
    def printPatientDetail(self):
        print("name:", self.name)
        print("Age", self.age)
        print("Symptoms:", self.sym)
        
        
p1 = Patient("Thomas", 23)
p1.add_Symptom("Headache")
p2 = Patient("Carol", 20)
p2.add_Symptom("Vomiting", "Coughing")
p3 = Patient("Mike", 25)
p3.add_Symptom("Fever", "Headache", "Coughing")
print("=========================")
p1.printPatientDetail()
print("=========================")
p2.printPatientDetail()
print("=========================")
p3.printPatientDetail()
print("=========================")
# Out:
# ...
# name: Thomas
# Age 23
# Symptoms: Headache
# ...
# name: Carol
# Age 20
# Symptoms: Vomiting, Coughing
# ...
# name: Mike
# Age 25
# Symptoms: Fever, Headache, Coughing
# ...

# %%
#TASK 10
class Avengers:
    def __init__(self, name, partner):
        self.name= name
        self.partner= partner
    
    def super_powers(self, *sup_pow):
        str_1= ""
        for i in sup_pow:
            str_1+= i+ ", "
        sup_pow= str_1[:len(str_1)-2]    
        self.sup_pow= sup_pow
        
    def printAvengersDetail(self):
        print("Name:", self.name)
        print("Partner:", self.partner)
        print("Super powers:", self.sup_pow)
        
a1 = Avengers('Captain America', 'Bucky Barnes')
a1.super_powers('Stamina', 'Slowed ageing')
a2 = Avengers('Doctor Strange', 'Ancient One')
a2.super_powers('Mastery of magic')
a3 = Avengers('Iron Man', 'War Machine')
a3.super_powers('Genius level intellect', 'Scientist ')
print("=========================")
a1.printAvengersDetail()
print("=========================")
a2.printAvengersDetail()
print("=========================")
a3.printAvengersDetail()
print("=========================")
# Out:
# ...
# Name: Captain America
# Partner: Bucky Barnes
# Super powers: Stamina, Slowed ageing
# ...
# Name: Doctor Strange
# Partner: Ancient One
# Super powers: Mastery of magic
# ...
# Name: Iron Man
# Partner: War Machine
# Super powers: Genius level intellect, Scientist
# ...

# %%
#TASK 11
class Shinobi:
    def __init__(self, name, rank):
        self.salary= 0
        self.mission= 0
        self.name= name
        self.rank= rank
        
    def changeRank(self, rank):
        self.rank= rank

    def calSalary(self, mission):
        self.mission= mission
        
        if self.rank== "Genin":
            self.salary= self.mission*50
        elif self.rank== "Chunin":
            self.salary= self.mission*100
        else:
            self.salary= self.mission*500

    def printInfo(self):
        print("Name:", self.name)
        print("Rank:", self.rank)
        print("Number of mission:", self.mission)
        print("Salary:", self.salary)
    
naruto = Shinobi("Naruto", "Genin")
naruto.calSalary(5)
naruto.printInfo()
print('====================')
shikamaru = Shinobi('Shikamaru', "Genin")
shikamaru.printInfo()
shikamaru.changeRank("Chunin")
shikamaru.calSalary(10)
shikamaru.printInfo()
print('====================')
neiji = Shinobi("Neiji", "Jonin")
neiji.calSalary(5)
neiji.printInfo()
# Out:
# Name: Naruto
# Rank: Genin
# Number of mission: 5
# Salary: 250
# ...
# Name: Shikamaru
# Rank: Genin
# Number of mission: 0
# Salary: 0
# Name: Shikamaru
# Rank: Chunin
# Number of mission: 10
# Salary: 1000
# ...
# Name: Neiji
# Rank: Jonin
# Number of mission: 5
# Salary: 2500

# %%
#TASK 12
class ParcelKoro:
    def __init__(self, name= "No name set", prod= 0):
        self.name= name
        self.product_weight= prod
        
    def calculateFee(self, loc= None):
        if self.product_weight== 0:
            self.fee= 0
        else:
            if loc== None:
                self.fee= (self.product_weight*20)+ 50
            else:
                self.fee= (self.product_weight*20)+ 100
                        
    def printDetails(self):
        print("Customer Name:", self.name)
        print("Product Weight:", self.product_weight)
        print("Total fee:", self.fee)
        
        
print("**********************")
p1 = ParcelKoro()
p1.calculateFee()
p1.printDetails()
print("**********************")
p2 = ParcelKoro('Bob The Builder')
p2.calculateFee()
p2.printDetails()
print("----------------------------")
p2.product_weight = 15
p2.calculateFee()
p2.printDetails()
print("**********************")
p3 = ParcelKoro('Dora The Explorer', 10)
p3.calculateFee('Dhanmondi')
p3.printDetails()
# Out:
# **********************
# Customer Name: No name set
# Product Weight: 0
# Total fee: 0
# **********************
# Customer Name: Bob The Builder
# Product Weight: 0
# Total fee: 0
# ----------------------------
# Customer Name: Bob The Builder
# Product Weight: 15
# Total fee: 350
# **********************
# Customer Name: Dora The Explorer
# Product Weight: 10
# Total fee: 300

# %%
#TASK 13
class Batsman:
    def __init__(self, *shelby):
        if len(shelby)== 3:
            self.name= shelby[0]
            self.run= shelby[1]
            self.ball= shelby[2]
        else:
            self.name= "New Batsman"
            self.run= shelby[0]
            self.ball= shelby[1]          
        
    def battingStrikeRate(self):
        return (self.run/self.ball)* 100
    
    def setName(self, name):
        self.name= name
        
    def printCareerStatistics(self):
        print("Name:", self.name)
        print(f"Runs Scored: {self.run}, Balls Faced: {self.ball}")
              
              
b1 = Batsman(6101, 7380)
b1.printCareerStatistics()
print("============================")
b2 = Batsman("Liton Das", 678, 773)
b2.printCareerStatistics()
print("----------------------------")
print(b2.battingStrikeRate())
print("============================")
b1.setName("Shakib Al Hasan")
b1.printCareerStatistics()
print("----------------------------")
print(b1.battingStrikeRate())
# Out:
# Name: New Batsman
# Runs Scored: 6101, Balls Faced: 7380
# ...
# Name: Liton Das
# Runs Scored: 678, Balls Faced: 773
# ----------------------------
# 87.71021992238033
# ...
# Name: Shakib Al Hasan
# Runs Scored: 6101, Balls Faced: 7380
# ----------------------------
# 82.66937669376694

# %%
#TASK 14
class EPL_Team:
    def __init__(self, name, song= " No Slogan"):
        self.name= name
        self.song= song
        self.title= 0
        
    def showClubInfo(self):
        return f"Name: {self.name}\nSong: {self.song}\nTotal No of title: {self.title}"
    
    def increaseTitle(self):
        self.title+= 1
        
    def changeSong(self, new_song):
        self.song= new_song
        
manu = EPL_Team('Manchester United', 'Glory Glory Man United')
chelsea = EPL_Team('Chelsea')
print('===================')
print(manu.showClubInfo())
print('##################')
manu.increaseTitle()
print(manu.showClubInfo())
print('===================')
print(chelsea.showClubInfo())
chelsea.changeSong('Keep the blue flag flying high')
print(chelsea.showClubInfo())
# Out:
# ...
# Name: Manchester United
# Song: Glory Glory Man United
# Total No of title: 0
# ##################
# Name: Manchester United
# Song: Glory Glory Man United
# Total No of title: 1
# ...
# Name: Chelsea
# Song:  No Slogan
# Total No of title: 0
# Name: Chelsea
# Song: Keep the blue flag flying high
# Total No of title: 0

# %%
#TASK 15
class Account:
    def __init__(self, name= "Default Account", amount= 0.0):
        self.name= name
        self.balance= amount

    def details(self):
        return f"{self.name}\n{self.balance}"
    
    def withdraw(self, amount):
        if self.balance<amount:
            print("Sorry, Withdraw unsuccessful! The account\nbalance after \
deducting withdraw amount is\nequal to or less than minimum")
        else:
            print("Withdraw successful! New balance is:", self.balance-amount)
    
a1 = Account()
print(a1.details())
print("------------------------")
a1.name = "Oliver"
a1.balance = 10000.0
print(a1.details())
print("------------------------")
a2 = Account("Liam")
print(a2.details())
print("------------------------")
a3 = Account("Noah",400)
print(a3.details())
print("------------------------")
a2.withdraw(6930);
print("------------------------")
a2.withdraw(600);
print("------------------------")
a1.withdraw(6929)
# Out:
# Default Account
# 0.0
# ------------------------
# Oliver
# 10000.0
# ------------------------
# Liam
# 0.0
# ------------------------
# Noah
# 400
# ------------------------
# Sorry, Withdraw unsuccessful! The account
# balance after deducting withdraw amount is
# equal to or less than minimum
# ------------------------
# Sorry, Withdraw unsuccessful! The account
# balance after deducting withdraw amount is
# equal to or less than minimum
# ------------------------
# Withdraw successful! New balance is: 3071.0

# %%
#TASK 16
class Author:
    def __init__(self, author= "Default", *book_name):
        self.name= author
        self.book_name= []
        for i in book_name:
            self.book_name.append(i)
            
    def changeName(self, new_author):
        self.name= new_author  

    def addBooks(self,*book_name):
        for i in book_name:
            self.book_name.append(i)
        
    def printDetails(self):
        print("Author Name:", self.name)
        print("--------")
        print("List of Books:")        
        for i in self.book_name:
            print(i)
              
                
auth1 = Author('Humayun Ahmed')
auth1.addBooks('Deyal', 'Megher Opor Bari')
auth1.printDetails()
print('===================')
auth2 = Author()
print(auth2.name)
auth2.changeName('Mario Puzo')
auth2.addBooks('The Godfather', 'Omerta', 'The Sicilian')
print('===================')
auth2.printDetails()
print('===================')
auth3 = Author('Paolo Coelho', 'The Alchemist', 'The Fifth Mountain')
auth3.printDetails()
# Out:
# Author Name: Humayun Ahmed
# --------
# List of Books:
# Deyal
# Megher Opor Bari
# ...
# Default
# ...
# Author Name: Mario Puzo
# --------
# List of Books:
# The Godfather
# Omerta
# The Sicilian
# ...
# Author Name: Paolo Coelho
# --------
# List of Books:
# The Alchemist
# The Fifth Mountain

# %%
#ungraded
#TASK 17
class Student:
    def __init__(self, name= None, dept= None):
        if name== None and dept== None:
            self.name= ""
            self.dept= ""
            print("Student name and department need to be set" )      
        elif dept== None:
            self.name= name
            print(f"Department for {name} needs to be set")
        else:
            self.name= name
            self.dept= dept
            print(f"{name} is from {dept} department")

    def update_name(self, name):
        self.name= name
        
    def update_department(self, dept):
        self.dept= dept
        
    def enroll(self, *course):
        self.enroll= []
        for i in course:
            self.enroll.append(i)
            
    def printDetail(self):
        print("Name:", self.name)
        print("Department", self.dept)    
        print(f"{self.name} enrolled in {len(self.enroll)} course(s)")
        str_1= ""
        for i in self.enroll:
            str_1+= i+ ", "
        print(str_1[:len(str_1)-2])     
        
        
        
s1 = Student()
print("=========================")
s2 = Student("Carol")
print("=========================")
s3 = Student("Jon", "EEE")
print("=========================")
s1.update_name("Bob")
s1.update_department("CSE")
s2.update_department("BBA")
s1.enroll("CSE110", "MAT110", "ENG091")
s2.enroll("BUS101")
s3.enroll("MAT110", "PHY111")
print("###########################")
s1.printDetail()
print("=========================")
s2.printDetail()
print("=========================")
s3.printDetail()
# Out:
# Student name and department need to be set
# ...
# Department for Carol needs to be set
# ...
# Jon is from EEE department
# ...
# ###########################
# Name: Bob
# Department CSE
# Bob enrolled in 3 course(s)
# CSE110, MAT110, ENG091
# ...
# Name: Carol
# Department BBA
# Carol enrolled in 1 course(s)
# BUS101
# ...
# Name: Jon
# Department EEE
# Jon enrolled in 2 course(s)
# MAT110, PHY111

# %%
# TASK 18
class Student:
    def __init__(self, name, id, dept):
        self.name = name
        self.id = id
        self.dept = dept

    def details(self):
        return f"Name: {self.name}\nID: {self.id}\nDepartment: {self.dept}"


    def advise(self, *course):
        str_1= ""
        counter= 0
        for i in course:
            str_1+= i+ ", "
            counter+= 1

        if counter<3:
            print(f"{self.name}, you have taken {counter*3.0} credits.")
            print("List of courses:", str_1[:len(str_1)-2])
            print(f"Status: You have to take at least {3-counter} more course.")
        elif 3<=counter<=4:
            print(f"{self.name}, you have taken {counter*3.0} credits.")
            print("List of courses:", str_1[:len(str_1)-2])
            print("Status: Ok")
        else:
            print(f"{self.name}, you have taken {counter*3.0} credits.")
            print("List of courses:", str_1[:len(str_1)-2])
            print(f"Status: You have to drop at least {counter-3} course.")


s1 = Student("Alice", "20103012", "CSE")
s2 = Student("Bob", "18301254", "EEE")
s3 = Student("Carol", "17101238", "CSE")
print("##########################")
print(s1.details())
print("##########################")
print(s2.details())
print("##########################")
s1.advise("CSE110", "MAT110", "PHY111")
print("##########################")
s2.advise("BUS101", "MAT120")
print("##########################")
s3.advise("MAT110", "PHY111", "ENG102", "CSE111", "CSE230")
# Out:
# ##########################
# Name: Alice
# ID: 20103012
# Department: CSE
# ##########################
# Name: Bob
# ID: 18301254
# Department: EEE
# ##########################
# Alice, you have taken 9.0 credits.
# List of courses: CSE110, MAT110, PHY111
# Status: Ok
# ##########################
# Bob, you have taken 6.0 credits.
# List of courses: BUS101, MAT120
# Status: You have to take at least 1 more course.
# ##########################
# Carol, you have taken 15.0 credits.
# List of courses: MAT110, PHY111, ENG102, CSE111, CSE230
# Status: You have to drop at least 2 course.

# %%
#TASK 19
class Hotel:
    num_staff= 0
    num_guest= 0
    dict_staff= {}
    dict_guest= {}
    list_staff= []
    list_guest= []
    
    def __init__(self, name):
        pass
        
    def addStuff(self, name, age, ph_no= "000"):       
        Hotel.num_staff+= 1
        Hotel.dict_staff["Staff ID:"]= Hotel.num_staff
        Hotel.dict_staff["Name:"]= name
        Hotel.dict_staff["Age:"]= age
        Hotel.dict_staff["Phone no.:"]= ph_no
        Hotel.list_staff.append(f"Staff ID: {Hotel.num_staff} Name: {name} Age:\
 {age} Phone no: {ph_no}")
        print(f"Staff With ID {Hotel.num_staff} is added")
        
    def getStuffById(self, id):
        str_1= ""
        for k,v in Hotel.dict_staff.items():
            str_1= f"{str_1}{k} {str(v)}\n"
        return str_1.strip() 
    
    def addGuest(self, name, age, ph_no):       
        Hotel.num_guest+= 1
        Hotel.dict_guest["Guest ID:"]= Hotel.num_guest
        Hotel.dict_guest["Name:"]= name
        Hotel.dict_guest["Age:"]= age
        Hotel.dict_guest["Phone no.:"]= ph_no
        Hotel.list_guest.append(f"Guest ID: {Hotel.num_guest} Name: {name} Age:\
 {age} Phone no: {ph_no}")
        print(f"Guest With ID {Hotel.num_guest} is created")    
    
    def getGuestById(self, id):
        str_1= ""
        for k,v in Hotel.dict_guest.items():
            str_1= f"{str_1}{k} {str(v)}\n"
        return str_1.strip()  
    
    def allStaffs(self):
        print(f"All Staffs:\nNumber of Staff: {Hotel.num_staff}")
        for i in Hotel.list_staff:
            print(i)
            
    def allGuest(self):
        print(f"All Guest:\nNumber of Guest: {Hotel.num_guest}")        
        for i in Hotel.list_guest:
            print(i)

        
h = Hotel("Lakeshore")
h.addStuff( "Adam", 26)
print("=================================")
print(h.getStuffById(1))
print("=================================")
h.addGuest("Carol",35,"123")
print("=================================")
print(h.getGuestById(1))
print("=================================")
h.addGuest("Diana", 32, "431")
print("=================================")
print(h.getGuestById(2))
print("=================================")
h.allStaffs()
print("=================================")
h.allGuest()
# Out:
# Staff With ID 1 is added
# ...
# Staff ID: 1
# Name: Adam
# Age: 26
# Phone no.: 000
# ...
# Guest With ID 1 is created
# ...
# Guest ID: 1
# Name: Carol
# Age: 35
# Phone no.: 123
# ...
# Guest With ID 2 is created
# ...
# Guest ID: 2
# Name: Diana
# Age: 32
# Phone no.: 431
# ...
# All Staffs:
# Number of Staff: 1
# Staff ID: 1 Name: Adam Age: 26 Phone no: 000
# ...
# All Guest:
# Number of Guest: 2
# Guest ID: 1 Name: Carol Age: 35 Phone no: 123
# Guest ID: 2 Name: Diana Age: 32 Phone no: 431

# %%
#TASK 20
class Author:    
    def __init__(self,name= None):
        self.name= name
        self.total_books= 0
        self.book={}
        
    def addBook(self, book_name, genre):
        if self.name!= None:
            if genre in self.book.keys():
                self.book[genre].append(book_name)
            else:
                self.book[genre]=[book_name]
            self.total_books+= 1           
        else:
            print("A book can not be added without author name")
            
    def setName(self, name):
        self.name= name
        
    def printDetail(self):
        print("Number of Book(s):", self.total_books)
        print("Author Name:", self.name)
        for i in self.book:
            print(i, ":", end=" ")
            print(*self.book[i], sep=", ")

            
a1 = Author()
print("=================================")
a1.addBook("Ice", "Science Fiction")
print("=================================")
a1.setName("Anna Kavan")
a1.addBook("Ice", "Science Fiction")
a1.printDetail()
print("=================================")
a2 = Author("Humayun Ahmed")
a2.addBook("Onnobhubon", "Science Fiction")
a2.addBook("Megher Upor Bari", "Horror")
print("=================================")
a2.printDetail()
a2.addBook("Ireena", "Science Fiction")
print("=================================")
a2.printDetail()
print("=================================")
# Out:
# ...
# A book can not be added without author name
# ...
# Number of Book(s): 1
# Author Name: Anna Kavan
# Science Fiction : Ice
# ...
# Number of Book(s): 2
# Author Name: Humayun Ahmed
# Science Fiction : Onnobhubon
# Horror : Megher Upor Bari
# ...
# Number of Book(s): 3
# Author Name: Humayun Ahmed
# Science Fiction : Onnobhubon, Ireena
# Horror : Megher Upor Bari
# ...

# %%
#TASK 21
class Doctor:
    def __init__(self, id, type, name, speciality):
        self.id= id
        self.type= type
        self.name= name
        self.spc= speciality
        
        
class Patient:
    def __init__(self, id, type, name, age, ph_no):
        self.id= id
        self.type= type
        self.name= name
        self.age= age
        self.ph_no= ph_no     
        
        
class Hospital:
    num_doctor= 0
    num_patient= 0
    dict_doctor= {}
    dict_patient= {}
    dict_alldoctor= {}
    dict_allpatient= {}
    
    def __init__(self, name):
        pass
    
    def addDoctor(self, initial):
        Hospital.num_doctor+= 1
        Hospital.dict_doctor["Doctor's ID:"]= initial.id
        Hospital.dict_doctor["Name:"]= initial.name
        Hospital.dict_doctor["Speciality:"]= initial.spc
        Hospital.dict_alldoctor[initial.id]= [initial.name, initial.spc]
    
    def getDoctorByID(self, id):
        str_1 = ""
        for k, v in Hospital.dict_doctor.items():
            str_1 = f"{str_1}{k} {str(v)}\n"
        return str_1.strip() 
    
    def addPatient(self, initial):
        Hospital.num_patient+= 1
        Hospital.dict_patient["Patient's ID:"]= initial.id
        Hospital.dict_patient["Name:"]= initial.name
        Hospital.dict_patient["Age:"]= initial.age
        Hospital.dict_patient["Phone no.:"]= initial.ph_no
        Hospital.dict_allpatient[initial.id]= [initial.name, initial.age, initial.ph_no]
    
    def getPatientByID(self, id):
        str_1 = ""
        for k, v in Hospital.dict_patient.items():
            str_1 = f"{str_1}{k} {str(v)}\n"
        return str_1.strip()
    
    def allDoctors(self):
        print(f"All Doctors:\nNumber of Doctors: {Hospital.num_doctor}")
        print(Hospital.dict_alldoctor)
        
    def allPatients(self):
        print(f"All Patients:\nNumber of Patients: {Hospital.num_patient}")
        print(Hospital.dict_allpatient)        
            

        
h = Hospital("Evercare")
d1 = Doctor("1d","Doctor", "Samar Kumar", "Neurologist")
h.addDoctor(d1)
print("=================================")
print(h.getDoctorByID("1d"))
print("=================================")
p1 = Patient("1p","Patient", "Kashem Ahmed", 35, 12345)
h.addPatient(p1)
print("=================================")
print(h.getPatientByID("1p"))
print("=================================")
p2 = Patient ("2p","Patient", "Tanina Haque", 26, 33456)
h.addPatient(p2)
print("=================================")
print(h.getPatientByID("2p"))
print("=================================")
h.allDoctors()
h.allPatients()
# Out:
# ...
# Doctor's ID: 1d
# Name: Samar Kumar
# Speciality: Neurologist
# ...
# Patient's ID: 1p
# Name: Kashem Ahmed
# Age: 35
# Phone no.: 12345
# ...
# Patient's ID: 2p
# Name: Tanina Haque
# Age: 26
# Phone no.: 33456
# ...
# All Doctors:
# Number of Doctors: 1
# {'1d': ['Samar Kumar', 'Neurologist']}
# All Patients:
# Number of Patients: 2
# {'1p': ['Kashem Ahmed', 35, 12345], '2p': ['Tanina Haque', 26, 33456]}

# %%
#TASK 22
class Vaccine:
    def __init__(self, vac_name, country, time):
        self.vac_name= vac_name
        self.country= country
        self.time= time
        
        
class Person:
    dose_name= None
    num_dose= 0
    first_dose= None
    sec_dose= None
    def __init__(self, name, age= -1, type= "General Citizen"):
        self.name= name
        self.age= age
        self.type= type

    def pushVaccine(self, VAC_name, dose_num= None):
        self.dose_num= dose_num
        if (self.age== -1 or self.age>= 25) or self.type== "Student":
            if self.dose_num== None:
                Person.dose_name= VAC_name.vac_name
                Person.num_dose+= 1
                Person.first_dose= "Given"
                Person.sec_dose= f"Please come after {VAC_name.time} days"
                print(f"1st dose done for {self.name}")
            elif Person.dose_name== VAC_name.vac_name:
                Person.num_dose+= 1
                Person.sec_dose= 'Given'
                print(f"2nd dose done for {self.name}")
            elif Person.dose_name!= VAC_name.vac_name:     
                print(f"Sorry {self.name}, you can’t take 2 different vaccines")
        else: 
            print(f"Sorry {self.name}, Minimum age for taking vaccines is \n25 years now.")
                       
    def showDetail(self):
        print(f"Name: {self.name} Age: {self.age} Type: {self.type}\nVaccine name: {Person.dose_name}\n\
1st dose: {Person.first_dose}\n2nd dose: {Person.sec_dose}")
        
        
        
        
astra = Vaccine("AstraZeneca", "UK", 60)
modr = Vaccine("Moderna", "UK", 30)
sin = Vaccine("Sinopharm", "China", 30)
p1 = Person("Bob", 21, "Student")
print("=================================")
p1.pushVaccine(astra)
print("=================================")
p1.showDetail()
print("=================================")
p1.pushVaccine(sin, "2nd Dose")
print("=================================")
p1.pushVaccine(astra, "2nd Dose")
print("=================================")
p1.showDetail()
print("=================================")
p2 = Person("Carol", 23, "Actor")
print("=================================")
p2.pushVaccine(sin)
print("=================================")
p3 = Person("David", 34)
print("=================================")
p3.pushVaccine(modr)
print("=================================")
p3.showDetail()
print("=================================")
p3.pushVaccine(modr, "2nd Dose")
# Out:
# ...
# 1st dose done for Bob
# ...
# Name: Bob Age: 21 Type: Student
# Vaccine name: AstraZeneca
# 1st dose: Given
# 2nd dose: Please come after 60 days
# ...
# Sorry Bob, you can’t take 2 different vaccines
# ...
# 2nd dose done for Bob
# ...
# Name: Bob Age: 21 Type: Student
# Vaccine name: AstraZeneca
# 1st dose: Given
# 2nd dose: Given
# ...
# Sorry Carol, Minimum age for taking vaccines is
# 25 years now.
# ...
# 1st dose done for David
# ...
# Name: David Age: 34 Type: General Citizen
# Vaccine name: Moderna
# 1st dose: Given
# 2nd dose: Please come after 30 days
# ...
# 2nd dose done for David
